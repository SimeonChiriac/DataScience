# %% [markdown]
# # Casusopdracht: onderzoeksvragen en eerste verkenning
#
# Onderdelen van dit jupyter notebook:
#
# 1. De eerste 4 stappen van dataverkenning worden toegepast op de gegeven dataset van de Fifa casus.
#
# 2. Er worden 4 concept-onderzoeksvragen opgesteld.
#
# 3. De onderzoeksvragen worden toegelicht waar nodig, en er wordt verwezen naar een externe dataset die als bijlage is ingeleverd op canvas naast deze notebook.

# %% [markdown]
# ## 1. Dataverkenning Fifa dataset

# %%
import pandas as pandas
import numpy as np

# %%
fifaSpelers = pandas.read_csv('/fifa19.csv',
                           sep=",", header=0)

# %% [markdown]
# ## 1.1 Verkenning van de dataset

# %%
fifaSpelers.head()
# Out:
#    Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0           0  158023  ...        8.0         €226.5M
# 1           1   20801  ...       11.0         €127.1M
# 2           2  190871  ...       11.0         €228.1M
# 3           3  193080  ...       94.0         €138.6M
# 4           4  192985  ...       13.0         €196.4M
#
# [5 rows x 89 columns]

# %% [markdown]
# ## 1.2 Data cleaning
#
# Hieronder wordt er gekeken of er dubbele waarden in onze dataset staan.

# %%
fifaSpelers.duplicated(subset=None, keep='first')
uplicateRowsDF = studenten[studenten.duplicated()]
print(uplicateRowsDF)
print(np.std(fifaSpelers))
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value, Wage, Special, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Real Face, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, LS, ST, RS, LW, LF, CF, RF, RW, LAM, CAM, RAM, LM, LCM, CM, RCM, RM, LWB, LDM, CDM, RDM, RWB, LB, LCB, CB, RCB, RB, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Release Clause]
# Index: []
#
# [0 rows x 89 columns]
# Unnamed: 0                   5255.908168
# ID                          29964.421288
# ...

# %% [markdown]
# ## 1.3 Data exploration and analysis

# %% [markdown]
# ## 2. Concept-onderzoeksvragen
#
# Eisen aan de onderzoeksvragen:
#
# 1.            Een uitbreiding van de toegewezen dataset met een externe dataset.
# 2.            Een verkenning van de data met relevante statistische analyses.
# 3.            Een interactieve visualisatie.
# 4.            Een correlatieonderzoek.
# 5.            Toepassing van een supervised machine learning techniek.
# 6.            Toepassing van een unsupervised machine learning techniek.
# 7.            Een hypothesetoets met behulp van de Z-test.
#
#
# Concept hoofdvragen
#
# 1. (verplichte onderzoeksvraag)
# In hoeverre is de waarde van een speler te voorspellen aan de hand van zijn belangrijkste kenmerken? eis nummer 5.
#
# 2. Wat zijn belangrijkste kenmerken van de voetbalspelers in het spel? Aan eis nummer 2 en eis nummer 4 worden hiermee voldaan.
#
# 3. In hoeverre komt de rating (overall waarde) van een speler in Fifa overeen met zijn waarde in het echt? Aan eis nummer 1.
#
# 4. Tussen welke kenmerken is er een aantoonbaar verband?
# Eis 3, 6.
#
# 5. Een voetbalcommentator beweert dat de potentie van de huidige generatie Engelse spelers sterk verschilt van spelers uit de rest van de wereld.
# Onderzoek met de dataset of de commentator gelijk heeft. Neem een steekproef van 100 Engelse spelers en beschouw de hele dataset als populatie. Kies als betrouwbaarheid 95%. Eis 7.
